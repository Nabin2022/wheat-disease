# %% [markdown]
# # Wheat Plant Disease Classification: Comparative Study
#
# This notebook compares transfer learning performance of VGG16, MobileNetV2, ResNet50, and DenseNet121 on the Kaggle Wheat Plant Diseases dataset, using accuracy, precision, recall, and F1-score.

# %% [markdown]
# ## Setup
#
# Requirements
# - Python 3.9+
# - TensorFlow 2.13+
# - scikit-learn, pandas, matplotlib, seaborn
# - Kaggle API credentials
#
# Install dependencies
# - `pip install -r requirements.txt`
#
# Kaggle credentials
# 1. Create a Kaggle API token (kaggle.json).
# 2. Place it at ~/.kaggle/kaggle.json or set environment variables KAGGLE_USERNAME and KAGGLE_KEY.

# %%
import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ## Training Strategy
#
# We use each pretrained CNN as a fixed feature extractor (base frozen).
# Only the custom classifier head is trained; base weights are not updated.
#
# Resume option: set `RESUME_FROM_CHECKPOINT = True` to continue training from saved checkpoints in `artifacts/`.
#
# Key hyperparameters to tune if needed: `INITIAL_EPOCHS`, `INITIAL_LR`, `PATIENCE`.

# %%
SEED = 42
IMG_SIZE = 224
BATCH_SIZE = 32

# Training hyperparameters (feature extractor; base frozen)
INITIAL_EPOCHS = 50
INITIAL_LR = 1e-3
PATIENCE = 13
RESUME_FROM_CHECKPOINT = True  # set True to continue training from saved checkpoints
AUTOTUNE = tf.data.AUTOTUNE

def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

set_seed()

print('TensorFlow:', tf.__version__)
gpus = tf.config.list_physical_devices('GPU')
print('GPUs:', gpus)
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as exc:
        print('Could not set memory growth:', exc)
# Out:
# TensorFlow: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPUs: []

# %%
import json

DATA_DIR = Path('data')
DATA_ROOT = DATA_DIR / 'Wheat Disease Dataset'

def get_data_root():
    if DATA_ROOT.exists():
        return DATA_ROOT
    return find_image_root(DATA_DIR)


try:
    data_root = get_data_root()
    print('Data directory already populated:', data_root.resolve())
except FileNotFoundError:
    raise FileNotFoundError(
        'No dataset found under data/. Place your dataset folder under data/Wheat Disease Dataset.'
    )
# Out:
# Data directory already populated: C:\Users\it\Desktop\wheat\data\Wheat Disease Dataset

# %%
import json
from pathlib import Path

IMAGE_EXTS = {'.jpg', '.jpeg', '.png'}

def has_images(path):
    return any(p.suffix.lower() in IMAGE_EXTS for p in path.iterdir() if p.is_file())

def find_image_root(base_dir):
    base_dir = Path(base_dir)
    for p in [base_dir] + list(base_dir.rglob('*')):
        if not p.is_dir():
            continue
        subdirs = [d for d in p.iterdir() if d.is_dir() and d.name.lower() != 'augmented']
        if not subdirs:
            continue
        if all(has_images(d) for d in subdirs):
            return p
    raise FileNotFoundError('Could not find an image root with class subfolders.')

data_root = DATA_ROOT if DATA_ROOT.exists() else find_image_root(DATA_DIR)
print('Image root:', data_root)

merge_map = {
    # Keep YellowRust as a separate class for augmented data
}

raw_classes = sorted([d.name for d in data_root.iterdir() if d.is_dir() and d.name.lower() != 'augmented'])
print('Raw classes:', raw_classes)

class_names = sorted({merge_map.get(name, name) for name in raw_classes})
print('Classes:', class_names)

# Save class names for inference apps
ARTIFACTS_DIR = Path('artifacts')
ARTIFACTS_DIR.mkdir(exist_ok=True)
(ARTIFACTS_DIR / 'class_names.json').write_text(json.dumps(class_names, indent=2))

# Saved paths dictionary mapping each model to its saved file
saved_paths = {
    'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
    'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
    'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
    'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    'GoogLeNet': ARTIFACTS_DIR / 'GoogLeNet_best.keras' if (ARTIFACTS_DIR / 'GoogLeNet_best.keras').exists() else ARTIFACTS_DIR / 'GoogLeNet.keras',
}
saved_path = saved_paths
# Out:
# Image root: data\Wheat Disease Dataset
# Raw classes: ['BrownRust', 'Healthy', 'Mildew', 'Septoria', 'YellowRust']
# Classes: ['BrownRust', 'Healthy', 'Mildew', 'Septoria', 'YellowRust']

# %%
image_paths = []
labels = []
class_to_index = {name: i for i, name in enumerate(class_names)}
bad_files = []

for cls in raw_classes:
    target_cls = merge_map.get(cls, cls)
    for p in (data_root / cls).rglob('*'):
        if p.suffix.lower() in IMAGE_EXTS:
            try:
                img_bytes = tf.io.read_file(str(p))
                _ = tf.image.decode_image(img_bytes, channels=3, expand_animations=False)
                image_paths.append(str(p))
                labels.append(class_to_index[target_cls])
            except Exception:
                bad_files.append(str(p))

print('Total images:', len(image_paths))
print('Unreadable images:', len(bad_files))

label_map = {v: k for k, v in class_to_index.items()}
df = pd.DataFrame({'path': image_paths, 'label': labels})
df['class'] = df['label'].map(label_map)
display(df['class'].value_counts())
# Out:
# Total images: 5872
# Unreadable images: 0
# class
# Septoria      1479
# Mildew        1174
# BrownRust     1159
# YellowRust    1097
# Healthy        963
# Name: count, dtype: int64

# %%
def show_samples(df, n=9):
    samples = df.sample(min(n, len(df)), random_state=SEED)
    rows = int(np.ceil(n / 3))
    plt.figure(figsize=(10, 3 * rows))
    for i, (_, row) in enumerate(samples.iterrows()):
        img = tf.io.read_file(row['path'])
        img = tf.image.decode_image(img, channels=3, expand_animations=False)
        img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
        plt.subplot(rows, 3, i + 1)
        plt.imshow(tf.cast(img, tf.uint8))
        plt.title(row['class'])
        plt.axis('off')
    plt.tight_layout()

show_samples(df, n=9)

# %%
# Use .to_numpy() to ensure compatibility with sklearn
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    df['path'].to_numpy(),    # Changed from .values
    df['label'].to_numpy(),   # Changed from .values
    test_size=0.3,
    stratify=df['label'].to_numpy(), # Changed from .values
    random_state=SEED,
)

val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths,
    temp_labels,
    test_size=0.5,
    stratify=temp_labels,
    random_state=SEED,
)
print('Train/Val/Test:', len(train_paths), len(val_paths), len(test_paths))
# Out:
# Train/Val/Test: 4110 881 881

# %%
# Advanced Data Augmentation Pipeline for Plant Leaf Diseases
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3)),
    # Geometric transformations (orientation & scale invariance)
    tf.keras.layers.RandomFlip('horizontal_and_vertical', name='random_flip'),
    tf.keras.layers.RandomRotation(0.15, fill_mode='reflect', name='random_rotation'),
    tf.keras.layers.RandomZoom((-0.15, 0.15), fill_mode='reflect', name='random_zoom'),
    tf.keras.layers.RandomTranslation(0.08, 0.08, fill_mode='reflect', name='random_translation'),
    # Photometric transformations (lighting, shadow & sensor variations)
    tf.keras.layers.RandomContrast(0.15, name='random_contrast'),
    tf.keras.layers.RandomBrightness(0.15, value_range=(0.0, 255.0), name='random_brightness'),
], name='plant_disease_augmentation')


def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)
    return img, label


def make_dataset(paths, labels, training=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if training:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(load_image, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE)
    if training:
        # Apply real-time on-the-fly stochastic augmentation during training
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
    ds = ds.prefetch(AUTOTUNE)
    return ds


train_ds = make_dataset(train_paths, train_labels, training=True)
val_ds = make_dataset(val_paths, val_labels, training=False)
test_ds = make_dataset(test_paths, test_labels, training=False)

# Visualize original vs. augmented samples
sample_path = train_paths[0]
raw_img, _ = load_image(sample_path, train_labels[0])
plt.figure(figsize=(12, 3))
plt.subplot(1, 5, 1)
plt.imshow(tf.cast(raw_img, tf.uint8))
plt.title('Original', fontweight='bold')
plt.axis('off')

for i in range(4):
    aug_img = data_augmentation(tf.expand_dims(raw_img, 0), training=True)[0]
    plt.subplot(1, 5, i + 2)
    plt.imshow(tf.cast(tf.clip_by_value(aug_img, 0, 255), tf.uint8))
    plt.title(f'Augmented {i+1}')
    plt.axis('off')
plt.suptitle('Data Augmentation Pipeline Demonstration', fontsize=13, y=1.05)
plt.tight_layout()
plt.show()

# %%
# Optional: Offline Data Augmentation
# Note: Real-time data augmentation is also active in Cell 10 via tf.data.
SAVE_OFFLINE_AUGMENTED = True

if SAVE_OFFLINE_AUGMENTED:
    import shutil
    AUGMENTED_DIR = DATA_DIR / "augmented"
    AUGMENTED_DIR.mkdir(parents=True, exist_ok=True)

    def generate_and_save_augmented_data(image_paths, labels, class_names, output_dir, augmentations_per_image=2, dataset_type='train'):
        """
        Generate augmented images and save them to separate folders by class.
        """
        dataset_dir = output_dir / dataset_type
        if dataset_dir.exists():
            shutil.rmtree(dataset_dir)
        dataset_dir.mkdir(parents=True, exist_ok=True)

        for class_idx, class_name in enumerate(class_names):
            class_dir = dataset_dir / class_name
            class_dir.mkdir(parents=True, exist_ok=True)

        print(f'Saving augmented {dataset_type} data...')

        for img_idx, (path, label) in enumerate(zip(image_paths, labels)):
            class_name = class_names[label]
            class_dir = dataset_dir / class_name

            img = tf.io.read_file(str(path))
            img = tf.image.decode_image(img, channels=3, expand_animations=False)
            img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
            img = tf.cast(img, tf.float32)

            for aug_idx in range(augmentations_per_image):
                augmented_img = data_augmentation(tf.expand_dims(img, 0), training=True)[0]
                augmented_img = tf.clip_by_value(augmented_img, 0, 255)
                augmented_img = tf.cast(augmented_img, tf.uint8)

                original_name = Path(path).stem
                output_filename = f'{original_name}_aug_{aug_idx}.jpg'
                output_path = class_dir / output_filename
                tf.keras.preprocessing.image.save_img(str(output_path), augmented_img.numpy())

            if (img_idx + 1) % max(1, len(image_paths) // 10) == 0:
                print(f'  Processed {img_idx + 1}/{len(image_paths)} images...')

        print(f'[OK] Augmented {dataset_type} data saved to: {dataset_dir}')

    # Execute generation for dataset splits
    generate_and_save_augmented_data(train_paths, train_labels, class_names, AUGMENTED_DIR, augmentations_per_image=2, dataset_type='train')
    generate_and_save_augmented_data(val_paths, val_labels, class_names, AUGMENTED_DIR, augmentations_per_image=2, dataset_type='val')
    generate_and_save_augmented_data(test_paths, test_labels, class_names, AUGMENTED_DIR, augmentations_per_image=2, dataset_type='test')
    print(f'\n✓ All augmented data saved successfully! Location: {AUGMENTED_DIR}')
else:
    print('Offline disk augmentation is disabled. On-the-fly augmentation is active in Cell 10.')
# Out:
# Saving augmented train data...
#   Processed 411/4110 images...
#   Processed 822/4110 images...
#   Processed 1233/4110 images...
#   Processed 1644/4110 images...
#   Processed 2055/4110 images...
#   Processed 2466/4110 images...
#   Processed 2877/4110 images...
#   Processed 3288/4110 images...
#   Processed 3699/4110 images...
#   Processed 4110/4110 images...
# [OK] Augmented train data saved to: data\augmented\train
# Saving augmented val data...
#   Processed 88/881 images...
#   Processed 176/881 images...
#   Processed 264/881 images...
#   Processed 352/881 images...
#   Processed 440/881 images...
#   Processed 528/881 images...
#   Processed 616/881 images...
#   Processed 704/881 images...
#   Processed 792/881 images...
#   Processed 880/881 images...
# [OK] Augmented val data saved to: data\augmented\val
# Saving augmented test data...
#   Processed 88/881 images...
#   Processed 176/881 images...
#   Processed 264/881 images...
#   Processed 352/881 images...
#   Processed 440/881 images...
#   Processed 528/881 images...
#   Processed 616/881 images...
#   Processed 704/881 images...
#   Processed 792/881 images...
#   Processed 880/881 images...
# [OK] Augmented test data saved to: data\augmented\test
#
# ✓ All augmented data saved successfully! Location: data\augmented

# %%
class_weights_arr = compute_class_weight(class_weight='balanced', classes=np.unique(train_labels), y=train_labels)
class_weights = {i: w for i, w in enumerate(class_weights_arr)}
class_weights
# Out:
# {0: np.float64(0.9718079673135853),
#  1: np.float64(1.2104325699745546),
#  2: np.float64(1.0948216340621404),
#  3: np.float64(0.9104306220095694),
#  4: np.float64(0.8825602968460111)}

# %%
def build_model(base_name, base_fn, preprocess_fn, num_classes):
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = preprocess_fn(inputs)
    base = base_fn(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base.trainable = False
    x = base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Stronger classification head
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.5)(x)

    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs, name=f'{base_name}_transfer')

    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR),
        loss=loss_fn,
        metrics=['accuracy'],
    )
    return model, base

# %%
def train_head_only(
    model,
    train_ds,
    val_ds,
    class_weights,
    initial_epochs=INITIAL_EPOCHS,
    initial_lr=INITIAL_LR,
    patience=PATIENCE,
    checkpoint_path=None,
):
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=max(2, patience//2), min_lr=1e-6),
    ]

    if checkpoint_path is not None:
        callbacks.append(
            tf.keras.callbacks.ModelCheckpoint(
                filepath=str(checkpoint_path),
                monitor='val_loss',
                save_best_only=True,
                save_weights_only=False,
                verbose=1,
            )
        )

    # Train only the classifier head (base remains frozen)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=initial_lr),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=['accuracy'],
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=initial_epochs,
        class_weight=class_weights,
        callbacks=callbacks,
        verbose=1,
    )

    return history

# %%
RESUME_FROM_CHECKPOINT = True

# %%
ARTIFACTS_DIR = Path('artifacts')

# Define saved model paths with fallback to existing checkpoints or models
saved_paths = {
    'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
    'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
    'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
    'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    'GoogLeNet': ARTIFACTS_DIR / 'GoogLeNet_best.keras' if (ARTIFACTS_DIR / 'GoogLeNet_best.keras').exists() else ARTIFACTS_DIR / 'GoogLeNet.keras',
}
saved_path = saved_paths

vgg_model = tf.keras.models.load_model(saved_paths['VGG16']) if saved_paths['VGG16'].exists() else None
mobile_model = tf.keras.models.load_model(saved_paths['MobileNetV2']) if saved_paths['MobileNetV2'].exists() else None
resnet_model = tf.keras.models.load_model(saved_paths['ResNet50']) if saved_paths['ResNet50'].exists() else None
densenet_model = tf.keras.models.load_model(saved_paths['DenseNet121']) if saved_paths['DenseNet121'].exists() else None
googlenet_model = tf.keras.models.load_model(saved_paths['GoogLeNet']) if saved_paths['GoogLeNet'].exists() else None

# %%
model_configs = {
    'VGG16': (tf.keras.applications.VGG16, tf.keras.applications.vgg16.preprocess_input),
    'MobileNetV2': (tf.keras.applications.MobileNetV2, tf.keras.applications.mobilenet_v2.preprocess_input),
    'ResNet50': (tf.keras.applications.ResNet50, tf.keras.applications.resnet50.preprocess_input),
    'DenseNet121': (tf.keras.applications.DenseNet121, tf.keras.applications.densenet.preprocess_input),
    # GoogLeNet is the original Inception family; InceptionV3 is its maintained
    # TensorFlow/Keras implementation with ImageNet transfer-learning weights.
    'GoogLeNet': (tf.keras.applications.InceptionV3, tf.keras.applications.inception_v3.preprocess_input),
}

results = []
histories = {}

ARTIFACTS_DIR = Path('artifacts')
ARTIFACTS_DIR.mkdir(exist_ok=True)

# Define and populate saved paths for all models
saved_paths = {
    name: (ARTIFACTS_DIR / f'{name}_best.keras') if (ARTIFACTS_DIR / f'{name}_best.keras').exists() else (ARTIFACTS_DIR / f'{name}.keras')
    for name in model_configs
}
saved_path = saved_paths

num_classes = len(class_names)

# %%
for name, (base_fn, preprocess_fn) in model_configs.items():
    tf.keras.backend.clear_session()
    print(f'Training {name} (base frozen)')

    ckpt_path = ARTIFACTS_DIR / f'{name}_best.keras'
    model = None
    

    # If you want to resume training from a previous checkpoint, set RESUME_FROM_CHECKPOINT = True
    if RESUME_FROM_CHECKPOINT and ckpt_path.exists():
        try:
            loaded_model = tf.keras.models.load_model(ckpt_path)
            if loaded_model.output_shape[-1] == num_classes:
                print(f'Resuming from checkpoint: {ckpt_path}')
                model = loaded_model
            else:
                print(
                    f'WARNING: checkpoint {ckpt_path} was trained for {loaded_model.output_shape[-1]} classes, '
                    f'but the current dataset has {num_classes} classes. '
                    f'Skipping this checkpoint and rebuilding the model from scratch for {name}.'
                )
        except Exception as exc:
            print(
                f'WARNING: failed to load checkpoint {ckpt_path} ({exc}). '
                f'Rebuilding the model from scratch for {name}.'
            )

    # Otherwise start fresh from the pretrained base
    if model is None:
        model, _base = build_model(name, base_fn, preprocess_fn, num_classes)

    history = train_head_only(
        model,
        train_ds,
        val_ds,
        class_weights,
        checkpoint_path=ckpt_path,
    )
    histories[name] = history

    # Load best checkpoint if available
    if ckpt_path.exists():
        model = tf.keras.models.load_model(ckpt_path)

    y_prob = model.predict(test_ds)
    y_pred = np.argmax(y_prob, axis=1)
    y_true = np.array(test_labels)

    acc = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)

    results.append({
        'model': name,
        'accuracy': acc,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
    })

    model_path = ARTIFACTS_DIR / f'{name}.keras'
    model.save(model_path)
    saved_paths[name] = model_path
    saved_path[name] = model_path
    print(f'Saved: {model_path}')
# Out:
# Training VGG16 (base frozen)
# Resuming from checkpoint: C:\Users\it\Desktop\New folder (6)\wheats\artifacts\VGG16_best.keras
# Epoch 1/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9694 - loss: 0.0889
# Epoch 1: val_loss improved from None to 0.20947, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\VGG16_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 445s 3s/step - accuracy: 0.9638 - loss: 0.1011 - val_accuracy: 0.9342 - val_loss: 0.2095 - learning_rate: 0.0010
# Epoch 2/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9700 - loss: 0.0926
# Epoch 2: val_loss did not improve from 0.20947
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 430s 3s/step - accuracy: 0.9685 - loss: 0.0960 - val_accuracy: 0.9441 - val_loss: 0.2123 - learning_rate: 0.0010
# Epoch 3/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9623 - loss: 0.1020
# Epoch 3: val_loss did not improve from 0.20947
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 429s 3s/step - accuracy: 0.9598 - loss: 0.1122 - val_accuracy: 0.9372 - val_loss: 0.2140 - learning_rate: 0.0010
# Epoch 4/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9575 - loss: 0.1140
# Epoch 4: val_loss improved from 0.20947 to 0.18964, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\VGG16_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 432s 3s/step - accuracy: 0.9590 - loss: 0.1164 - val_accuracy: 0.9431 - val_loss: 0.1896 - learning_rate: 0.0010
# Epoch 5/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9615 - loss: 0.1042
# Epoch 5: val_loss improved from 0.18964 to 0.17524, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\VGG16_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 430s 3s/step - accuracy: 0.9636 - loss: 0.1056 - val_accuracy: 0.9529 - val_loss: 0.1752 - learning_rate: 0.0010
# Epoch 6/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9707 - loss: 0.0907
# Epoch 6: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 427s 3s/step - accuracy: 0.9701 - loss: 0.0855 - val_accuracy: 0.9490 - val_loss: 0.1966 - learning_rate: 0.0010
# Epoch 7/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9699 - loss: 0.0833
# Epoch 7: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 427s 3s/step - accuracy: 0.9680 - loss: 0.0898 - val_accuracy: 0.9362 - val_loss: 0.2275 - learning_rate: 0.0010
# Epoch 8/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9667 - loss: 0.0906
# Epoch 8: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 426s 3s/step - accuracy: 0.9662 - loss: 0.0930 - val_accuracy: 0.9441 - val_loss: 0.1825 - learning_rate: 0.0010
# Epoch 9/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9708 - loss: 0.0836
# Epoch 9: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 424s 3s/step - accuracy: 0.9680 - loss: 0.0884 - val_accuracy: 0.9411 - val_loss: 0.2078 - learning_rate: 0.0010
# Epoch 10/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9646 - loss: 0.1022
# Epoch 10: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 426s 3s/step - accuracy: 0.9586 - loss: 0.1147 - val_accuracy: 0.9352 - val_loss: 0.2303 - learning_rate: 0.0010
# Epoch 11/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9628 - loss: 0.0965
# Epoch 11: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 425s 3s/step - accuracy: 0.9649 - loss: 0.0925 - val_accuracy: 0.9441 - val_loss: 0.1989 - learning_rate: 0.0010
# Epoch 12/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9762 - loss: 0.0701
# Epoch 12: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 426s 3s/step - accuracy: 0.9748 - loss: 0.0727 - val_accuracy: 0.9401 - val_loss: 0.1830 - learning_rate: 5.0000e-04
# Epoch 13/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9798 - loss: 0.0622
# Epoch 13: val_loss did not improve from 0.17524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 423s 3s/step - accuracy: 0.9783 - loss: 0.0694 - val_accuracy: 0.9441 - val_loss: 0.1887 - learning_rate: 5.0000e-04
# Epoch 14/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9747 - loss: 0.0728
# Epoch 14: val_loss improved from 0.17524 to 0.17017, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\VGG16_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 424s 3s/step - accuracy: 0.9760 - loss: 0.0683 - val_accuracy: 0.9549 - val_loss: 0.1702 - learning_rate: 5.0000e-04
# Epoch 15/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9785 - loss: 0.0567
# Epoch 15: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 424s 3s/step - accuracy: 0.9802 - loss: 0.0554 - val_accuracy: 0.9441 - val_loss: 0.1967 - learning_rate: 5.0000e-04
# Epoch 16/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9854 - loss: 0.0401
# Epoch 16: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 429s 3s/step - accuracy: 0.9838 - loss: 0.0443 - val_accuracy: 0.9490 - val_loss: 0.1800 - learning_rate: 5.0000e-04
# Epoch 17/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9840 - loss: 0.0482
# Epoch 17: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 454s 3s/step - accuracy: 0.9855 - loss: 0.0455 - val_accuracy: 0.9549 - val_loss: 0.1776 - learning_rate: 5.0000e-04
# Epoch 18/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9835 - loss: 0.0416
# Epoch 18: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 445s 3s/step - accuracy: 0.9832 - loss: 0.0423 - val_accuracy: 0.9500 - val_loss: 0.1825 - learning_rate: 5.0000e-04
# Epoch 19/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9811 - loss: 0.0559
# Epoch 19: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 446s 3s/step - accuracy: 0.9840 - loss: 0.0494 - val_accuracy: 0.9500 - val_loss: 0.1996 - learning_rate: 5.0000e-04
# Epoch 20/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9849 - loss: 0.0446
# Epoch 20: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 444s 3s/step - accuracy: 0.9861 - loss: 0.0381 - val_accuracy: 0.9519 - val_loss: 0.1970 - learning_rate: 5.0000e-04
# Epoch 21/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9879 - loss: 0.0353
# Epoch 21: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 425s 3s/step - accuracy: 0.9878 - loss: 0.0360 - val_accuracy: 0.9549 - val_loss: 0.1839 - learning_rate: 2.5000e-04
# Epoch 22/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9890 - loss: 0.0300
# Epoch 22: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 429s 3s/step - accuracy: 0.9891 - loss: 0.0299 - val_accuracy: 0.9568 - val_loss: 0.1828 - learning_rate: 2.5000e-04
# Epoch 23/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9899 - loss: 0.0303
# Epoch 23: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 419s 3s/step - accuracy: 0.9880 - loss: 0.0348 - val_accuracy: 0.9549 - val_loss: 0.1869 - learning_rate: 2.5000e-04
# Epoch 24/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9908 - loss: 0.0278
# Epoch 24: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 420s 3s/step - accuracy: 0.9905 - loss: 0.0299 - val_accuracy: 0.9519 - val_loss: 0.1922 - learning_rate: 2.5000e-04
# Epoch 25/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9926 - loss: 0.0244
# Epoch 25: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 435s 3s/step - accuracy: 0.9916 - loss: 0.0273 - val_accuracy: 0.9588 - val_loss: 0.1848 - learning_rate: 2.5000e-04
# Epoch 26/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9915 - loss: 0.0261
# Epoch 26: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 436s 3s/step - accuracy: 0.9912 - loss: 0.0259 - val_accuracy: 0.9578 - val_loss: 0.1748 - learning_rate: 2.5000e-04
# Epoch 27/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9934 - loss: 0.0231
# Epoch 27: val_loss did not improve from 0.17017
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 427s 3s/step - accuracy: 0.9931 - loss: 0.0227 - val_accuracy: 0.9568 - val_loss: 0.1725 - learning_rate: 1.2500e-04
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step
# Saved: C:\Users\it\Desktop\New folder (6)\wheats\artifacts\VGG16.keras
# Training MobileNetV2 (base frozen)
# Resuming from checkpoint: C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# Epoch 1/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9862 - loss: 0.0394
# Epoch 1: val_loss improved from None to 0.24120, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 144s 930ms/step - accuracy: 0.9807 - loss: 0.0554 - val_accuracy: 0.9500 - val_loss: 0.2412 - learning_rate: 0.0010
# Epoch 2/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.9823 - loss: 0.0586
# Epoch 2: val_loss did not improve from 0.24120
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 137s 915ms/step - accuracy: 0.9746 - loss: 0.0771 - val_accuracy: 0.9362 - val_loss: 0.2604 - learning_rate: 0.0010
# Epoch 3/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.9677 - loss: 0.0954
# Epoch 3: val_loss improved from 0.24120 to 0.22333, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 938ms/step - accuracy: 0.9651 - loss: 0.1019 - val_accuracy: 0.9382 - val_loss: 0.2233 - learning_rate: 0.0010
# Epoch 4/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.9691 - loss: 0.0883
# Epoch 4: val_loss did not improve from 0.22333
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 142s 950ms/step - accuracy: 0.9720 - loss: 0.0837 - val_accuracy: 0.9293 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 5/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.9674 - loss: 0.0880
# Epoch 5: val_loss improved from 0.22333 to 0.21913, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 142s 946ms/step - accuracy: 0.9731 - loss: 0.0708 - val_accuracy: 0.9460 - val_loss: 0.2191 - learning_rate: 0.0010
# Epoch 6/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 782ms/step - accuracy: 0.9781 - loss: 0.0658
# Epoch 6: val_loss improved from 0.21913 to 0.19980, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 142s 947ms/step - accuracy: 0.9744 - loss: 0.0671 - val_accuracy: 0.9401 - val_loss: 0.1998 - learning_rate: 0.0010
# Epoch 7/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 776ms/step - accuracy: 0.9762 - loss: 0.0666
# Epoch 7: val_loss did not improve from 0.19980
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 141s 942ms/step - accuracy: 0.9739 - loss: 0.0705 - val_accuracy: 0.9500 - val_loss: 0.2004 - learning_rate: 0.0010
# Epoch 8/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.9751 - loss: 0.0697
# Epoch 8: val_loss improved from 0.19980 to 0.19069, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9771 - loss: 0.0701 - val_accuracy: 0.9500 - val_loss: 0.1907 - learning_rate: 0.0010
# Epoch 9/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.9812 - loss: 0.0533
# Epoch 9: val_loss improved from 0.19069 to 0.16837, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 143s 956ms/step - accuracy: 0.9796 - loss: 0.0591 - val_accuracy: 0.9627 - val_loss: 0.1684 - learning_rate: 0.0010
# Epoch 10/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 775ms/step - accuracy: 0.9803 - loss: 0.0595
# Epoch 10: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 143s 955ms/step - accuracy: 0.9783 - loss: 0.0637 - val_accuracy: 0.9480 - val_loss: 0.2006 - learning_rate: 0.0010
# Epoch 11/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 885ms/step - accuracy: 0.9766 - loss: 0.0619
# Epoch 11: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9769 - loss: 0.0636 - val_accuracy: 0.9460 - val_loss: 0.2266 - learning_rate: 0.0010
# Epoch 12/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.9801 - loss: 0.0618
# Epoch 12: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 139s 927ms/step - accuracy: 0.9790 - loss: 0.0612 - val_accuracy: 0.9500 - val_loss: 0.2131 - learning_rate: 0.0010
# Epoch 13/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.9751 - loss: 0.0651
# Epoch 13: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 139s 929ms/step - accuracy: 0.9771 - loss: 0.0631 - val_accuracy: 0.9509 - val_loss: 0.1872 - learning_rate: 0.0010
# Epoch 14/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.9803 - loss: 0.0569
# Epoch 14: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 933ms/step - accuracy: 0.9790 - loss: 0.0623 - val_accuracy: 0.9539 - val_loss: 0.2132 - learning_rate: 0.0010
# Epoch 15/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.9767 - loss: 0.0627
# Epoch 15: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 932ms/step - accuracy: 0.9762 - loss: 0.0662 - val_accuracy: 0.9411 - val_loss: 0.2287 - learning_rate: 0.0010
# Epoch 16/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9889 - loss: 0.0345
# Epoch 16: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 139s 926ms/step - accuracy: 0.9865 - loss: 0.0368 - val_accuracy: 0.9519 - val_loss: 0.2211 - learning_rate: 5.0000e-04
# Epoch 17/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.9871 - loss: 0.0379
# Epoch 17: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 139s 927ms/step - accuracy: 0.9863 - loss: 0.0390 - val_accuracy: 0.9558 - val_loss: 0.1872 - learning_rate: 5.0000e-04
# Epoch 18/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.9915 - loss: 0.0284
# Epoch 18: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 138s 921ms/step - accuracy: 0.9878 - loss: 0.0349 - val_accuracy: 0.9480 - val_loss: 0.2152 - learning_rate: 5.0000e-04
# Epoch 19/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.9909 - loss: 0.0248
# Epoch 19: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 933ms/step - accuracy: 0.9899 - loss: 0.0295 - val_accuracy: 0.9568 - val_loss: 0.1992 - learning_rate: 5.0000e-04
# Epoch 20/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - accuracy: 0.9926 - loss: 0.0237
# Epoch 20: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 139s 925ms/step - accuracy: 0.9922 - loss: 0.0236 - val_accuracy: 0.9470 - val_loss: 0.2019 - learning_rate: 5.0000e-04
# Epoch 21/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.9882 - loss: 0.0298
# Epoch 21: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 935ms/step - accuracy: 0.9891 - loss: 0.0302 - val_accuracy: 0.9549 - val_loss: 0.2165 - learning_rate: 5.0000e-04
# Epoch 22/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 774ms/step - accuracy: 0.9925 - loss: 0.0216
# Epoch 22: val_loss did not improve from 0.16837
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 935ms/step - accuracy: 0.9912 - loss: 0.0261 - val_accuracy: 0.9578 - val_loss: 0.2052 - learning_rate: 2.5000e-04
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 790ms/step
# Saved: C:\Users\it\Desktop\New folder (6)\wheats\artifacts\MobileNetV2.keras
# Training ResNet50 (base frozen)
# Resuming from checkpoint: C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# Epoch 1/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9887 - loss: 0.0332
# Epoch 1: val_loss improved from None to 0.14905, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 316s 2s/step - accuracy: 0.9895 - loss: 0.0337 - val_accuracy: 0.9657 - val_loss: 0.1490 - learning_rate: 0.0010
# Epoch 2/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9807 - loss: 0.0585
# Epoch 2: val_loss did not improve from 0.14905
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 307s 2s/step - accuracy: 0.9788 - loss: 0.0628 - val_accuracy: 0.9598 - val_loss: 0.1823 - learning_rate: 0.0010
# Epoch 3/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9741 - loss: 0.0710
# Epoch 3: val_loss improved from 0.14905 to 0.14588, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 315s 2s/step - accuracy: 0.9762 - loss: 0.0654 - val_accuracy: 0.9578 - val_loss: 0.1459 - learning_rate: 0.0010
# Epoch 4/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9806 - loss: 0.0614
# Epoch 4: val_loss improved from 0.14588 to 0.13767, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - accuracy: 0.9821 - loss: 0.0515 - val_accuracy: 0.9686 - val_loss: 0.1377 - learning_rate: 0.0010
# Epoch 5/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9804 - loss: 0.0557
# Epoch 5: val_loss did not improve from 0.13767
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - accuracy: 0.9788 - loss: 0.0605 - val_accuracy: 0.9568 - val_loss: 0.1852 - learning_rate: 0.0010
# Epoch 6/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9782 - loss: 0.0555
# Epoch 6: val_loss improved from 0.13767 to 0.12405, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 313s 2s/step - accuracy: 0.9796 - loss: 0.0540 - val_accuracy: 0.9686 - val_loss: 0.1241 - learning_rate: 0.0010
# Epoch 7/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9876 - loss: 0.0421
# Epoch 7: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9865 - loss: 0.0436 - val_accuracy: 0.9666 - val_loss: 0.1454 - learning_rate: 0.0010
# Epoch 8/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9852 - loss: 0.0415
# Epoch 8: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 309s 2s/step - accuracy: 0.9838 - loss: 0.0432 - val_accuracy: 0.9715 - val_loss: 0.1354 - learning_rate: 0.0010
# Epoch 9/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9847 - loss: 0.0412
# Epoch 9: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9819 - loss: 0.0507 - val_accuracy: 0.9676 - val_loss: 0.1436 - learning_rate: 0.0010
# Epoch 10/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9850 - loss: 0.0412
# Epoch 10: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9851 - loss: 0.0454 - val_accuracy: 0.9715 - val_loss: 0.1241 - learning_rate: 0.0010
# Epoch 11/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9859 - loss: 0.0359
# Epoch 11: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9830 - loss: 0.0459 - val_accuracy: 0.9745 - val_loss: 0.1432 - learning_rate: 0.0010
# Epoch 12/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9895 - loss: 0.0349
# Epoch 12: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9878 - loss: 0.0392 - val_accuracy: 0.9676 - val_loss: 0.1427 - learning_rate: 0.0010
# Epoch 13/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9924 - loss: 0.0222
# Epoch 13: val_loss did not improve from 0.12405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9922 - loss: 0.0232 - val_accuracy: 0.9686 - val_loss: 0.1258 - learning_rate: 5.0000e-04
# Epoch 14/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9916 - loss: 0.0278
# Epoch 14: val_loss improved from 0.12405 to 0.12366, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9933 - loss: 0.0240 - val_accuracy: 0.9745 - val_loss: 0.1237 - learning_rate: 5.0000e-04
# Epoch 15/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9924 - loss: 0.0201
# Epoch 15: val_loss improved from 0.12366 to 0.12288, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 308s 2s/step - accuracy: 0.9914 - loss: 0.0210 - val_accuracy: 0.9735 - val_loss: 0.1229 - learning_rate: 5.0000e-04
# Epoch 16/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9924 - loss: 0.0211
# Epoch 16: val_loss improved from 0.12288 to 0.12075, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9922 - loss: 0.0215 - val_accuracy: 0.9706 - val_loss: 0.1208 - learning_rate: 5.0000e-04
# Epoch 17/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9965 - loss: 0.0114
# Epoch 17: val_loss did not improve from 0.12075
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9954 - loss: 0.0141 - val_accuracy: 0.9666 - val_loss: 0.1298 - learning_rate: 5.0000e-04
# Epoch 18/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9905 - loss: 0.0221
# Epoch 18: val_loss improved from 0.12075 to 0.11350, saving model to C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50_best.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9916 - loss: 0.0223 - val_accuracy: 0.9715 - val_loss: 0.1135 - learning_rate: 5.0000e-04
# Epoch 19/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9960 - loss: 0.0129
# Epoch 19: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9943 - loss: 0.0159 - val_accuracy: 0.9706 - val_loss: 0.1269 - learning_rate: 5.0000e-04
# Epoch 20/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9959 - loss: 0.0114
# Epoch 20: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9960 - loss: 0.0122 - val_accuracy: 0.9725 - val_loss: 0.1271 - learning_rate: 5.0000e-04
# Epoch 21/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9926 - loss: 0.0237
# Epoch 21: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9943 - loss: 0.0191 - val_accuracy: 0.9706 - val_loss: 0.1294 - learning_rate: 5.0000e-04
# Epoch 22/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9938 - loss: 0.0176
# Epoch 22: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 303s 2s/step - accuracy: 0.9945 - loss: 0.0153 - val_accuracy: 0.9686 - val_loss: 0.1289 - learning_rate: 5.0000e-04
# Epoch 23/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9969 - loss: 0.0140
# Epoch 23: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 303s 2s/step - accuracy: 0.9952 - loss: 0.0155 - val_accuracy: 0.9715 - val_loss: 0.1191 - learning_rate: 5.0000e-04
# Epoch 24/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9924 - loss: 0.0186
# Epoch 24: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9926 - loss: 0.0183 - val_accuracy: 0.9715 - val_loss: 0.1395 - learning_rate: 5.0000e-04
# Epoch 25/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9941 - loss: 0.0125
# Epoch 25: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9706 - val_loss: 0.1420 - learning_rate: 2.5000e-04
# Epoch 26/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9986 - loss: 0.0072
# Epoch 26: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - accuracy: 0.9981 - loss: 0.0088 - val_accuracy: 0.9725 - val_loss: 0.1336 - learning_rate: 2.5000e-04
# Epoch 27/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9984 - loss: 0.0056
# Epoch 27: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9686 - val_loss: 0.1326 - learning_rate: 2.5000e-04
# Epoch 28/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9951 - loss: 0.0110
# Epoch 28: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9958 - loss: 0.0109 - val_accuracy: 0.9706 - val_loss: 0.1260 - learning_rate: 2.5000e-04
# Epoch 29/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9983 - loss: 0.0071
# Epoch 29: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 303s 2s/step - accuracy: 0.9973 - loss: 0.0092 - val_accuracy: 0.9735 - val_loss: 0.1369 - learning_rate: 2.5000e-04
# Epoch 30/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9980 - loss: 0.0072
# Epoch 30: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9755 - val_loss: 0.1320 - learning_rate: 2.5000e-04
# Epoch 31/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9987 - loss: 0.0074
# Epoch 31: val_loss did not improve from 0.11350
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 303s 2s/step - accuracy: 0.9977 - loss: 0.0082 - val_accuracy: 0.9715 - val_loss: 0.1361 - learning_rate: 1.2500e-04
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step
# Saved: C:\Users\it\Desktop\New folder (6)\wheats\artifacts\ResNet50.keras

# %%
results_df = pd.DataFrame(results)
print(results_df.columns)
results_df
# Out:
# Index(['model', 'accuracy', 'precision', 'recall', 'f1_score'], dtype='object')
#          model  accuracy  precision    recall  f1_score
# 0        VGG16  0.948039   0.948182  0.948039  0.947951
# 1  MobileNetV2  0.961765   0.962419  0.961765  0.961821
# 2     ResNet50  0.980392   0.980676  0.980392  0.980464

# %%
train_val_results = []
for name, hist in histories.items():
    h = hist.history
    train_acc = h.get('accuracy', [None])[-1]
    val_acc = h.get('val_accuracy', [None])[-1]
    best_val_epoch = int(np.argmax(h['val_accuracy'])) + 1 if 'val_accuracy' in h else None
    best_val_acc = float(max(h['val_accuracy'])) if 'val_accuracy' in h else None
    train_val_results.append({
        'model': name,
        'train_accuracy_last_epoch': train_acc,
        'val_accuracy_last_epoch': val_acc,
        'best_val_accuracy': best_val_acc,
        'best_val_epoch': best_val_epoch,
    })

train_val_df = pd.DataFrame(train_val_results).sort_values('model').reset_index(drop=True)
train_val_df
# Out:
#          model  train_accuracy_last_epoch  val_accuracy_last_epoch  \
# 0  MobileNetV2                   0.991171                 0.957802
# 1     ResNet50                   0.997688                 0.971541
# 2        VGG16                   0.993063                 0.956820
#
#    best_val_accuracy  best_val_epoch
# 0           0.962709               9
# 1           0.975466              30
# 2           0.958783              25

# %%
# Individual accuracy and loss plots for each model
num_models = len(histories)
if num_models == 0:
    print("No trained models in histories. Run the training cell first.")
else:
    fig, axes = plt.subplots(num_models, 2, figsize=(14, 4 * num_models), squeeze=False)

    for idx, (name, hist) in enumerate(sorted(histories.items())):
        h = hist.history
        epochs = range(1, len(h['accuracy']) + 1)
        
        # Plot accuracy
        axes[idx, 0].plot(epochs, h['accuracy'], 'b-', label='Train Accuracy', linewidth=2)
        axes[idx, 0].plot(epochs, h['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2)
        axes[idx, 0].set_title(f'{name} - Training vs Validation Accuracy', fontsize=12, fontweight='bold')
        axes[idx, 0].set_xlabel('Epoch')
        axes[idx, 0].set_ylabel('Accuracy')
        axes[idx, 0].legend()
        axes[idx, 0].grid(True, alpha=0.3)
        
        # Plot loss
        axes[idx, 1].plot(epochs, h['loss'], 'b-', label='Train Loss', linewidth=2)
        axes[idx, 1].plot(epochs, h['val_loss'], 'r-', label='Validation Loss', linewidth=2)
        axes[idx, 1].set_title(f'{name} - Training vs Validation Loss', fontsize=12, fontweight='bold')
        axes[idx, 1].set_xlabel('Epoch')
        axes[idx, 1].set_ylabel('Loss')
        axes[idx, 1].legend()
        axes[idx, 1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
# VGG16 - Train and Validation Accuracy
import matplotlib.pyplot as plt
import numpy as np

if 'histories' not in globals() or 'VGG16' not in histories:
    print("VGG16 has not been trained yet in this session. Run the training cell (Cell 18) first.")
else:
    vgg_hist = histories['VGG16'].history
    epochs_vgg = range(1, len(vgg_hist['accuracy']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_vgg, vgg_hist['accuracy'], 'b-', label='Train Accuracy', linewidth=2.5, marker='o', markersize=4)
    plt.plot(epochs_vgg, vgg_hist['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2.5, marker='s', markersize=4)
    plt.title('VGG16 - Training vs Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim([0, 1.0])
    plt.tight_layout()
    plt.show()

    print(f"VGG16 - Train Accuracy (last epoch): {vgg_hist['accuracy'][-1]:.4f}")
    print(f"VGG16 - Validation Accuracy (last epoch): {vgg_hist['val_accuracy'][-1]:.4f}")
    print(f"VGG16 - Best Validation Accuracy: {max(vgg_hist['val_accuracy']):.4f} at epoch {np.argmax(vgg_hist['val_accuracy']) + 1}")
# Out:
# VGG16 - Train Accuracy (last epoch): 0.9931
# VGG16 - Validation Accuracy (last epoch): 0.9568
# VGG16 - Best Validation Accuracy: 0.9588 at epoch 25

# %%
# VGG16 - Training vs Validation Loss
import matplotlib.pyplot as plt
import numpy as np

if 'histories' not in globals() or 'VGG16' not in histories:
    print("VGG16 has not been trained yet in this session. Run the training cell (Cell 18) first.")
else:
    vgg_hist = histories['VGG16'].history
    epochs_vgg = range(1, len(vgg_hist['loss']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_vgg, vgg_hist['loss'], 'b-', label='Train Loss', linewidth=2.5, marker='o', markersize=4)
    plt.plot(epochs_vgg, vgg_hist['val_loss'], 'r-', label='Validation Loss', linewidth=2.5, marker='s', markersize=4)
    plt.title('VGG16 - Training vs Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    print(f"VGG16 - Train Loss (last epoch): {vgg_hist['loss'][-1]:.4f}")
    print(f"VGG16 - Validation Loss (last epoch): {vgg_hist['val_loss'][-1]:.4f}")
    print(f"VGG16 - Best Validation Loss: {min(vgg_hist['val_loss']):.4f} at epoch {np.argmin(vgg_hist['val_loss']) + 1}")
# Out:
# VGG16 - Train Loss (last epoch): 0.0227
# VGG16 - Validation Loss (last epoch): 0.1725
# VGG16 - Best Validation Loss: 0.1702 at epoch 14

# %%
# MobileNetV2 - Train and Validation Accuracy
import matplotlib.pyplot as plt
import numpy as np

if 'histories' not in globals() or 'MobileNetV2' not in histories:
    print("MobileNetV2 has not been trained yet in this session. Run the training cell (Cell 18) first.")
else:
    mobile_hist = histories['MobileNetV2'].history
    epochs_mobile = range(1, len(mobile_hist['accuracy']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_mobile, mobile_hist['accuracy'], 'b-', label='Train Accuracy', linewidth=2.5, marker='o', markersize=4)
    plt.plot(epochs_mobile, mobile_hist['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2.5, marker='s', markersize=4)
    plt.title('MobileNetV2 - Training vs Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim([0, 1.0])
    plt.tight_layout()
    plt.show()

    print(f"MobileNetV2 - Train Accuracy (last epoch): {mobile_hist['accuracy'][-1]:.4f}")
    print(f"MobileNetV2 - Validation Accuracy (last epoch): {mobile_hist['val_accuracy'][-1]:.4f}")
    print(f"MobileNetV2 - Best Validation Accuracy: {max(mobile_hist['val_accuracy']):.4f} at epoch {np.argmax(mobile_hist['val_accuracy']) + 1}")
# Out:
# MobileNetV2 - Train Accuracy (last epoch): 0.9912
# MobileNetV2 - Validation Accuracy (last epoch): 0.9578
# MobileNetV2 - Best Validation Accuracy: 0.9627 at epoch 9

# %%
# ResNet50 - Train and Validation Accuracy
import matplotlib.pyplot as plt
import numpy as np

if 'histories' not in globals() or 'ResNet50' not in histories:
    print("ResNet50 has not been trained yet in this session. Run the training cell (Cell 18) first.")
else:
    resnet_hist = histories['ResNet50'].history
    epochs_resnet = range(1, len(resnet_hist['accuracy']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_resnet, resnet_hist['accuracy'], 'b-', label='Train Accuracy', linewidth=2.5, marker='o', markersize=4)
    plt.plot(epochs_resnet, resnet_hist['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2.5, marker='s', markersize=4)
    plt.title('ResNet50 - Training vs Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim([0, 1.0])
    plt.tight_layout()
    plt.show()

    print(f"ResNet50 - Train Accuracy (last epoch): {resnet_hist['accuracy'][-1]:.4f}")
    print(f"ResNet50 - Validation Accuracy (last epoch): {resnet_hist['val_accuracy'][-1]:.4f}")
    print(f"ResNet50 - Best Validation Accuracy: {max(resnet_hist['val_accuracy']):.4f} at epoch {np.argmax(resnet_hist['val_accuracy']) + 1}")
# Out:
# ResNet50 - Train Accuracy (last epoch): 0.9977
# ResNet50 - Validation Accuracy (last epoch): 0.9715
# ResNet50 - Best Validation Accuracy: 0.9755 at epoch 30

# %%
histories
# Out:
# {'VGG16': <keras.src.callbacks.history.History at 0x1b8dc8017e0>,
#  'MobileNetV2': <keras.src.callbacks.history.History at 0x1b8df262980>,
#  'ResNet50': <keras.src.callbacks.history.History at 0x1b8de0d0a30>}

# %%
# VGG16 Confusion Matrix
from pathlib import Path

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

vgg_model_cm = tf.keras.models.load_model(saved_paths['VGG16'])
y_prob_vgg = vgg_model_cm.predict(test_ds)
y_pred_vgg = np.argmax(y_prob_vgg, axis=1)
y_true = np.array(test_labels)

cm_vgg = confusion_matrix(y_true, y_pred_vgg)
plt.figure(figsize=(8, 7))
sns.heatmap(cm_vgg, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names, cbar_kws={'label': 'Count'})
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.title('VGG16 - Confusion Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print("VGG16 - Classification Report:")
print(classification_report(y_true, y_pred_vgg, target_names=class_names, zero_division=0))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 114s 3s/step
# VGG16 - Classification Report:
#               precision    recall  f1-score   support
#
#    BrownRust       0.95      0.92      0.93       210
#      Healthy       0.94      0.95      0.94       168
#       Mildew       0.94      0.94      0.94       187
#     Septoria       0.94      0.98      0.96       224
#   YellowRust       0.96      0.95      0.96       231
#
#     accuracy                           0.95      1020
#    macro avg       0.95      0.95      0.95      1020
# weighted avg       0.95      0.95      0.95      1020

# %%
# VGG16 - ROC Curve (multiclass)
from pathlib import Path
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

# If y_prob_vgg has not been computed yet, load the model and compute predictions
if 'y_prob_vgg' not in globals():
    vgg_model_roc = tf.keras.models.load_model(saved_paths['VGG16'])
    y_prob_vgg = vgg_model_roc.predict(test_ds, verbose=0)

if 'y_true' not in globals():
    y_true = np.asarray(test_labels)

num_classes = len(class_names)
y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))

# Plot ROC curve for each disease class
plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob_vgg[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(
        fpr,
        tpr,
        linewidth=2,
        label=f"{class_name} (AUC = {roc_auc:.3f})"
    )

# Random-classifier reference line
plt.plot([0, 1], [0, 1], "k--", label="Random classifier")
plt.title("VGG16 - ROC Curves", fontsize=14, fontweight='bold')
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# MobileNetV2 Confusion Matrix
from pathlib import Path

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

mobile_model_cm = tf.keras.models.load_model(saved_paths['MobileNetV2'])
y_prob_mobile = mobile_model_cm.predict(test_ds)
y_pred_mobile = np.argmax(y_prob_mobile, axis=1)
y_true = np.array(test_labels)

cm_mobile = confusion_matrix(y_true, y_pred_mobile)
plt.figure(figsize=(8, 7))
sns.heatmap(cm_mobile, annot=True, fmt='d', cmap='Greens', xticklabels=class_names, yticklabels=class_names, cbar_kws={'label': 'Count'})
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.title('MobileNetV2 - Confusion Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print("MobileNetV2 - Classification Report:")
print(classification_report(y_true, y_pred_mobile, target_names=class_names, zero_division=0))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 885ms/step
# MobileNetV2 - Classification Report:
#               precision    recall  f1-score   support
#
#    BrownRust       0.97      0.95      0.96       210
#      Healthy       0.98      0.94      0.96       168
#       Mildew       0.92      0.97      0.95       187
#     Septoria       0.96      0.98      0.97       224
#   YellowRust       0.98      0.96      0.97       231
#
#     accuracy                           0.96      1020
#    macro avg       0.96      0.96      0.96      1020
# weighted avg       0.96      0.96      0.96      1020

# %%
# ResNet50 Confusion Matrix
from pathlib import Path

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

resnet_model_cm = tf.keras.models.load_model(saved_paths['ResNet50'])
y_prob_resnet = resnet_model_cm.predict(test_ds)
y_pred_resnet = np.argmax(y_prob_resnet, axis=1)
y_true = np.array(test_labels)

cm_resnet = confusion_matrix(y_true, y_pred_resnet)
plt.figure(figsize=(8, 7))
sns.heatmap(cm_resnet, annot=True, fmt='d', cmap='Oranges', xticklabels=class_names, yticklabels=class_names, cbar_kws={'label': 'Count'})
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.title('ResNet50 - Confusion Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print("ResNet50 - Classification Report:")
print(classification_report(y_true, y_pred_resnet, target_names=class_names, zero_division=0))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step
# ResNet50 - Classification Report:
#               precision    recall  f1-score   support
#
#    BrownRust       0.95      0.98      0.96       210
#      Healthy       0.98      0.98      0.98       168
#       Mildew       0.98      0.98      0.98       187
#     Septoria       0.99      0.98      0.99       224
#   YellowRust       1.00      0.98      0.99       231
#
#     accuracy                           0.98      1020
#    macro avg       0.98      0.98      0.98      1020
# weighted avg       0.98      0.98      0.98      1020

# %%
def predict_image(path, model, class_names):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)
    img = tf.expand_dims(img, axis=0)
    preds = model.predict(img)
    idx = int(np.argmax(preds[0]))
    return class_names[idx], float(preds[0][idx])

# Example usage:
# user_image_path = 'path/to/your/image.jpg'
# label, confidence = predict_image(user_image_path, best_model, class_names)
# print(label, confidence)

# %%
# Example usage:
if 'resnet_model' not in globals() or resnet_model is None:
    resnet_model = tf.keras.models.load_model(saved_paths['ResNet50'])

user_image_path = './data/Wheat Disease Dataset/Healthy/Healthy4.png'
label, confidence = predict_image(user_image_path, resnet_model, class_names)
print(label, confidence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Mildew 0.9850576519966125

# %%
# MobileNetV2 - Training vs Validation Loss
import matplotlib.pyplot as plt

if 'histories' not in globals() or 'MobileNetV2' not in histories:
    print("MobileNetV2 has not been trained yet in this session. Run the training cell (Cell 18) first.")
else:
    mobile_hist = histories['MobileNetV2'].history
    epochs_mobile = range(1, len(mobile_hist['loss']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_mobile, mobile_hist['loss'], color='royalblue', marker='o', markersize=4, linewidth=2, label='Training Loss')
    plt.plot(epochs_mobile, mobile_hist['val_loss'], color='crimson', marker='s', markersize=4, linewidth=2, label='Validation Loss')
    plt.title('MobileNetV2 - Training vs Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    if len(epochs_mobile) > 0:
        plt.xticks(epochs_mobile)
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# MobileNetV2 - Training vs Validation Loss
import matplotlib.pyplot as plt

if 'histories' not in globals() or 'MobileNetV2' not in histories:
    print("MobileNetV2 has not been trained yet in this session. Run the training cell (Cell 18) first.")
else:
    mobile_hist = histories['MobileNetV2'].history
    epochs_mobile = range(1, len(mobile_hist['loss']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_mobile, mobile_hist['loss'], label='Training Loss', color='royalblue', marker='o', markersize=4, linewidth=2)
    plt.plot(epochs_mobile, mobile_hist['val_loss'], label='Validation Loss', color='crimson', marker='s', markersize=4, linewidth=2)

    plt.title('MobileNetV2 - Training vs Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    if len(epochs_mobile) > 0:
        plt.xticks(epochs_mobile)
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# MobileNetV2 - ROC Curve (multiclass)
from pathlib import Path
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

# Load the best MobileNetV2 model
mobile_model = tf.keras.models.load_model(saved_paths["MobileNetV2"])

# Get predicted class probabilities
y_prob_mobile = mobile_model.predict(test_ds, verbose=0)

# True labels and one-hot/binary representation
y_true = np.asarray(test_labels)
num_classes = len(class_names)
y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))

# Plot ROC curve for each disease class
plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob_mobile[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr,
        tpr,
        linewidth=2,
        label=f"{class_name} (AUC = {roc_auc:.3f})"
    )

# Random-classifier reference line
plt.plot([0, 1], [0, 1], "k--", label="Random classifier")

plt.title("MobileNetV2 - ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ResNet50 - ROC Curve (multiclass)
from pathlib import Path
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

# Load the best trained ResNet50 model
resnet_model = tf.keras.models.load_model(saved_paths["ResNet50"])

# Get class probabilities for the test images
y_prob_resnet = resnet_model.predict(test_ds, verbose=0)

# Convert true numeric labels to one-vs-rest binary labels
y_true = np.asarray(test_labels)
num_classes = len(class_names)
y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))

# Plot one ROC curve per class
plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob_resnet[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr,
        tpr,
        linewidth=2,
        label=f"{class_name} (AUC = {roc_auc:.3f})"
    )

# Random classifier baseline
plt.plot([0, 1], [0, 1], "k--", label="Random classifier")

plt.title("ResNet50 - ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ResNet50 - Training vs Validation Loss
if 'ResNet50' not in histories:
    print("ResNet50 has not been trained yet in this session.")
else:
    resnet_hist = histories['ResNet50'].history
    epochs_resnet = range(1, len(resnet_hist['loss']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_resnet, resnet_hist['loss'], color='royalblue', marker='o', markersize=4, linewidth=2, label='Training Loss')
    plt.plot(epochs_resnet, resnet_hist['val_loss'], color='crimson', marker='s', markersize=4, linewidth=2, label='Validation Loss')
    plt.title('ResNet50 - Training vs Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.xticks(range(1, len(resnet_hist['loss']) + 1))
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# DenseNet121 - Train and Validation Accuracy
if 'DenseNet121' not in histories:
    print("DenseNet121 has not been trained yet in this session.")
else:
    densenet_hist = histories['DenseNet121'].history
    epochs_densenet = range(1, len(densenet_hist['accuracy']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_densenet, densenet_hist['accuracy'], 'b-', label='Train Accuracy', linewidth=2.5, marker='o', markersize=4)
    plt.plot(epochs_densenet, densenet_hist['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2.5, marker='s', markersize=4)
    plt.title('DenseNet121 - Training vs Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.xticks(range(1, len(densenet_hist['accuracy']) + 1))
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.show()

    print(f"DenseNet121 - Train Accuracy (last epoch): {densenet_hist['accuracy'][-1]:.4f}")
    print(f"DenseNet121 - Validation Accuracy (last epoch): {densenet_hist['val_accuracy'][-1]:.4f}")
    print(f"DenseNet121 - Best Validation Accuracy: {max(densenet_hist['val_accuracy']):.4f} (Epoch {np.argmax(densenet_hist['val_accuracy']) + 1})")

# %%
# DenseNet121 - Training vs Validation Loss
if 'DenseNet121' not in histories:
    print("DenseNet121 has not been trained yet in this session.")
else:
    densenet_hist = histories['DenseNet121'].history
    epochs_densenet = range(1, len(densenet_hist['loss']) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs_densenet, densenet_hist['loss'], color='royalblue', marker='o', markersize=4, linewidth=2, label='Training Loss')
    plt.plot(epochs_densenet, densenet_hist['val_loss'], color='crimson', marker='s', markersize=4, linewidth=2, label='Validation Loss')
    plt.title('DenseNet121 - Training vs Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.xticks(range(1, len(densenet_hist['loss']) + 1))
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# DenseNet121 Confusion Matrix
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

densenet_model_path = saved_paths['DenseNet121']
if not densenet_model_path.exists():
    print(f"DenseNet121 model file not found at {densenet_model_path}. Run training first.")
else:
    densenet_model_cm = tf.keras.models.load_model(densenet_model_path)
    y_prob_densenet = densenet_model_cm.predict(test_ds)
    y_pred_densenet = np.argmax(y_prob_densenet, axis=1)
    y_true = np.array(test_labels)

    cm_densenet = confusion_matrix(y_true, y_pred_densenet)
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm_densenet, annot=True, fmt='d', cmap='Purples', xticklabels=class_names, yticklabels=class_names, cbar_kws={'label': 'Count'})
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.title('DenseNet121 - Confusion Matrix', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

    print("DenseNet121 - Classification Report:")
    print(classification_report(y_true, y_pred_densenet, target_names=class_names, zero_division=0))

# %%
# DenseNet121 - ROC Curve (multiclass)
from pathlib import Path
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

if 'saved_paths' not in globals():
    ARTIFACTS_DIR = Path('artifacts')
    saved_paths = {
        'VGG16': ARTIFACTS_DIR / 'VGG16_best.keras' if (ARTIFACTS_DIR / 'VGG16_best.keras').exists() else ARTIFACTS_DIR / 'VGG16.keras',
        'MobileNetV2': ARTIFACTS_DIR / 'MobileNetV2_best.keras' if (ARTIFACTS_DIR / 'MobileNetV2_best.keras').exists() else ARTIFACTS_DIR / 'MobileNetV2.keras',
        'ResNet50': ARTIFACTS_DIR / 'ResNet50_best.keras' if (ARTIFACTS_DIR / 'ResNet50_best.keras').exists() else ARTIFACTS_DIR / 'ResNet50.keras',
        'DenseNet121': ARTIFACTS_DIR / 'DenseNet121_best.keras' if (ARTIFACTS_DIR / 'DenseNet121_best.keras').exists() else ARTIFACTS_DIR / 'DenseNet121.keras',
    }
    saved_path = saved_paths

densenet_model_path = saved_paths['DenseNet121']
if not densenet_model_path.exists():
    print(f"DenseNet121 model file not found at {densenet_model_path}. Run training first.")
else:
    densenet_model = tf.keras.models.load_model(densenet_model_path)
    y_prob_densenet = densenet_model.predict(test_ds, verbose=0)

    y_true = np.asarray(test_labels)
    num_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))

    plt.figure(figsize=(10, 8))

    for i, class_name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob_densenet[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(
            fpr,
            tpr,
            linewidth=2,
            label=f"{class_name} (AUC = {roc_auc:.3f})"
        )

    plt.plot([0, 1], [0, 1], "k--", label="Random classifier")
    plt.title("DenseNet121 - ROC Curves")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(loc="lower right")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
